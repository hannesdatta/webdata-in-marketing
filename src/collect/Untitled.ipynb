# %% [markdown]
# # Try out with web of science

# %%
api_key = 'a90a70e4eccdd584fa93fbd917f80e4cc286e4e8'
headers = {'X-ApiKey': api_key}

import requests
import json
import time
import math

# %%
id = 'WOS:000588620800006'

url = 'https://wos-api.clarivate.com/api/wos/citing/?databaseId=WOS&uniqueId=WOS:000270372400005&count=100&firstRecord=1&optionView=FR'


url = 'https://wos-api.clarivate.com/api/wos/references/?databaseId=WOS&uniqueId=WOS:000270372400005&count=100&firstRecord=1&optionView=FR'

response = requests.get(url, headers=headers)

f=open('test2.txt', 'w', encoding='utf-8')
f.write(response.text)
f.close()

# %%
response.json()
# Out:
# {'Data': [{'UID': 'WOS:000221447500009',
#    'CitedAuthor': 'Yassin, AS',
#    'TimesCited': '34',
#    'Year': '2004',
#    'Page': '324',
#    'Volume': '1',
#    'CitedWork': 'JOURNAL OF OCCUPATIONAL AND ENVIRONMENTAL HYGIENE',
#    'CitedTitle': 'Urinary cadmium levels in the US working population, 1988-1994',
#    'DOI': '10.1080/15459620490445499'},
#   {'UID': 'WOS:A1994MR98900033',
#    'CitedAuthor': 'MASTERS, BA',
#    'TimesCited': '585',
#    'Year': '1994',
#    'Page': '584',
#    'Volume': '91',
#    'CitedWork': 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA',
#    'CitedTitle': 'TARGETED DISRUPTION OF METALLOTHIONEIN-I AND METALLOTHIONEIN-II GENES INCREASES SENSITIVITY TO CADMIUM',
#    'DOI': '10.1073/pnas.91.2.584'},
#   {'UID': 'WOS:000266770400008',
#    'CitedAuthor': 'Chang, Xiuli',
#    'TimesCited': '27',
#    'Year': '2009',
#    'Page': '666',
#    'Volume': '234',
#    'CitedWork': 'EXPERIMENTAL BIOLOGY AND MEDICINE',
# ...

# %%
response.text
# Out:
# '{"Data":{"Records":{"records":{"REC":[{"UID":"WOS:000462864800004","static_data":{"summary":{"pub_info":{"coverdate":"MAY 2019","vol":113,"journal_oas_gold":"Y","pubyear":2019,"sortdate":"2019-05-01","has_abstract":"Y","pubmonth":"MAY","pubtype":"Journal","page":{"page_count":12}},"names":{"count":6,"name":[{"seq_no":1,"role":"author","full_name":"Joneidi, Zeinab","addr_no":1,"last_name":"Joneidi","display_name":"Joneidi, Zeinab","wos_standard":"Joneidi, Z","daisng_id":27859549,"first_name":"Zeinab"},{"seq_no":2,"role":"author","full_name":"Mortazavi, Yousef","addr_no":1,"last_name":"Mortazavi","display_name":"Mortazavi, Yousef","wos_standard":"Mortazavi, Y","daisng_id":37004868,"first_name":"Yousef"},{"seq_no":3,"role":"author","full_name":"Memari, Fatemeh","addr_no":2,"last_name":"Memari","display_name":"Memari, Fatemeh","wos_standard":"Memari, F","daisng_id":5079124,"first_name":"Fatemeh"},{"seq_no":4,"role":"author","full_name":"Roointan, Amir","addr_no":3,"last_name":"Roointan"
# ...
